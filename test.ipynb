# %%
test = 1
test_2 = "ali"

# %%
import time
import datetime

start = time.time()
while True:
  end = time.time()
  time_string = str(datetime.timedelta(seconds=end - start))
  print("\r"+time_string, end="")
